# %%
#!/usr/bin/env python3
"""
MVP: Lightweight US Stock Alerts (Form4 + NewsData)
- Uses official SEC Atom feed (no scraping)
- News via NewsData.io API
- Posts only MEDIUM/HIGH alerts to Discord
- Logs everything to 'bot.log'
"""

import os
import re
import time
import json
import logging
import sqlite3
import requests
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta
from dotenv import load_dotenv
from bs4 import BeautifulSoup
import pandas as pd
import pytz

# ------------------- CONFIG -------------------
load_dotenv()
DISCORD_WEBHOOK = os.getenv("DISCORD_WEBHOOK_URL") or "https://discord.com/api/webhooks/1435654882710519888/ZDx_dGG22dknR4hGrENapdaG1Cm-VyUCUvrXmI6kGxcw0KLILP5AJKmNB14L9TzD65J-"
NEWSDATA_KEY = os.getenv("NEWSDATA_API_KEY") or "pub_f22ba9249c104a038d7e1b904b949e3a"
DEDUPE_MINUTES = int(os.getenv("DEDUPE_WINDOW_MINUTES", "30"))
POLL_INTERVAL = int(os.getenv("POLL_INTERVAL_SECONDS", "90"))
WATCHLIST_SOURCE = os.getenv("WATCHLIST_SOURCE", "SP500")

USER_AGENT = {"User-Agent": "StockAI-Bot/1.1 (ajakovski@yahoo.com)"}
DB_PATH = "events.db"
LOG_FILE = "bot.log"

US_TZ = pytz.timezone("America/New_York")

# keywords
BUY_KEYWORDS = ["buy", "purchase", "acquire", "purchased", "bought"]
SELL_KEYWORDS = ["sell", "sold", "disposition", "sold out"]
CEO_KEYWORDS = ["chief executive", "ceo", "chief executive officer", "president"]
CFO_KEYWORDS = ["chief financial", "cfo", "chief financial officer"]
NEWS_ALERT_KEYWORDS = [
    "acquire", "merger", "buyback", "earnings", "downgrade", "upgrade",
    "surprise", "fraud", "restat", "guidance", "lawsuit", "sec investigation"
]

# ------------------- LOGGING -------------------
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
console.setFormatter(formatter)
logging.getLogger("").addHandler(console)

# ------------------- DATABASE -------------------
def init_db():
    conn = sqlite3.connect(DB_PATH)
    c = conn.cursor()
    c.execute("""
    CREATE TABLE IF NOT EXISTS events (
        id INTEGER PRIMARY KEY,
        source TEXT,
        ticker TEXT,
        event_type TEXT,
        role_flag TEXT,
        severity TEXT,
        title TEXT,
        link TEXT,
        raw TEXT,
        created_at TEXT
    )
    """)
    conn.commit()
    return conn

def already_seen(conn, source, ticker, event_type):
    c = conn.cursor()
    time_threshold = (datetime.utcnow() - timedelta(minutes=DEDUPE_MINUTES)).isoformat()
    c.execute("""
    SELECT 1 FROM events
    WHERE source=? AND ticker=? AND event_type=? AND created_at>?
    """, (source, ticker, event_type, time_threshold))
    return c.fetchone() is not None

def save_event(conn, data):
    c = conn.cursor()
    c.execute("""
    INSERT INTO events (source,ticker,event_type,role_flag,severity,title,link,raw,created_at)
    VALUES (?,?,?,?,?,?,?,?,?)
    """, (
        data.get("source"),
        data.get("ticker"),
        data.get("event_type"),
        data.get("role_flag"),
        data.get("severity"),
        data.get("title"),
        data.get("link"),
        data.get("raw"),
        datetime.utcnow().isoformat()
    ))
    conn.commit()

# ------------------- SEC FORM 4 -------------------
def fetch_recent_form4_entries():
    url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcurrent&type=4&output=atom"
    try:
        r = requests.get(url, headers=USER_AGENT, timeout=20)
        r.raise_for_status()
        root = ET.fromstring(r.content)
        ns = {'atom': 'http://www.w3.org/2005/Atom'}
        entries = []
        for entry in root.findall('atom:entry', ns):
            title = entry.find('atom:title', ns).text
            link = entry.find('atom:link', ns).attrib.get('href')
            summary = entry.find('atom:summary', ns)
            summary_text = summary.text if summary is not None else ""
            m = re.search(r"\(([A-Z0-9.-]{1,6})\)", title or "")
            ticker = m.group(1).upper() if m else None
            entries.append({
                "title": title,
                "link": link,
                "summary": summary_text,
                "ticker": ticker
            })
        logging.info(f"Fetched {len(entries)} Form4 entries from SEC.")
        return entries
    except Exception as e:
        logging.error(f"SEC Form4 fetch error: {e}")
        return []

def score_form4(entry_text):
    t = entry_text.lower()
    severity = "LOW"
    if any(kw in t for kw in BUY_KEYWORDS):
        severity = "MED"
    if any(kw in t for kw in CEO_KEYWORDS + CFO_KEYWORDS):
        severity = "HIGH"
    return severity

# ------------------- NEWSDATA -------------------
def fetch_news_newsdata(tickers):
    results = []
    if not NEWSDATA_KEY:
        logging.warning("No NewsData API key found.")
        return []

    try:
        for i in range(0, len(tickers), 8):  # smaller batches = safer
            subset = tickers[i:i + 8]
            # Use spaces, not plus signs, and keep "OR" uppercased
            query = " OR ".join(subset)
            params = {
                "apikey": NEWSDATA_KEY,
                "q": query,
                "language": "en",
            }
            url = "https://newsdata.io/api/1/news"
            r = requests.get(url, params=params, headers=USER_AGENT, timeout=20)

            if r.status_code == 422:
                logging.warning(f"NewsData skipped bad query batch: {subset}")
                time.sleep(1)
                continue

            r.raise_for_status()
            data = r.json()
            for item in data.get("results", []):
                results.append({
                    "title": item.get("title"),
                    "description": item.get("description") or "",
                    "url": item.get("link"),
                    "source": item.get("source_id"),
                    "published": item.get("pubDate")
                })
            logging.info(f"NewsData batch ok ({len(results)} total so far)")
            time.sleep(1.5)

        logging.info(f"Fetched {len(results)} total news articles from NewsData.io.")
        return results

    except Exception as e:
        logging.error(f"NewsData fetch error: {e}")
        return []


def score_news(article):
    text = (article.get("title", "") + " " + article.get("description", "")).lower()
    severity = "LOW"
    if any(kw in text for kw in NEWS_ALERT_KEYWORDS):
        severity = "MED"
    if any(kw in text for kw in ["merger", "acquisition", "buyback", "delisting"]):
        severity = "HIGH"
    return severity

# ------------------- DISCORD -------------------
def post_to_discord(payload):
    if not DISCORD_WEBHOOK:
        logging.warning("No Discord webhook configured.")
        return
    data = {
        "content": None,
        "embeds": [
            {
                "title": payload.get("title"),
                "description": payload.get("description"),
                "url": payload.get("link"),
                "fields": [
                    {"name": "Ticker", "value": payload.get("ticker") or "N/A", "inline": True},
                    {"name": "Source", "value": payload.get("source"), "inline": True},
                    {"name": "Severity", "value": payload.get("severity"), "inline": True}
                ],
                "timestamp": datetime.utcnow().isoformat()
            }
        ]
    }
    try:
        r = requests.post(DISCORD_WEBHOOK, json=data, timeout=10)
        if r.status_code not in (200, 204):
            logging.error(f"Discord error {r.status_code}: {r.text}")
    except Exception as e:
        logging.error(f"Discord post failed: {e}")

# ------------------- HELPERS -------------------
def load_sp500():
    try:
        url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
        r = requests.get(url, headers=USER_AGENT, timeout=15)
        soup = BeautifulSoup(r.text, "lxml")
        table = soup.find("table", {"id": "constituents"})
        df = pd.read_html(str(table))[0]
        tickers = set(df.Symbol.str.replace('.', '-', regex=False).str.upper().tolist())
        logging.info(f"Loaded {len(tickers)} S&P500 tickers.")
        return tickers
    except Exception as e:
        logging.error(f"S&P500 load failed: {e}")
        return set()

# ------------------- MAIN LOOP -------------------
def main_loop():
    conn = init_db()
    watchlist = load_sp500() if WATCHLIST_SOURCE == "SP500" else set()
    logging.info("Bot started successfully.")

    while True:
        try:
            # --- SEC Form 4 ---
            form4_entries = fetch_recent_form4_entries()
            for entry in form4_entries:
                if not entry.get("ticker") or entry["ticker"] not in watchlist:
                    continue
                text = entry.get("summary", "")
                severity = score_form4(text)
                if severity == "LOW":
                    continue
                if already_seen(conn, "form4", entry["ticker"], severity):
                    continue
                data = {
                    "source": "form4",
                    "ticker": entry["ticker"],
                    "event_type": "insider_tx",
                    "role_flag": None,
                    "severity": severity,
                    "title": f"Form4 Alert — {entry['ticker']} — {severity}",
                    "link": entry["link"],
                    "raw": text
                }
                save_event(conn, data)
                desc = f"**Event:** Insider transaction\n\n{entry['summary'][:600]}..."
                post_to_discord({
                    "title": data["title"],
                    "description": desc,
                    "link": data["link"],
                    "ticker": data["ticker"],
                    "source": "SEC Form 4",
                    "severity": severity
                })
                logging.info(f"Posted Form4 alert: {entry['ticker']} ({severity})")

            # --- NewsData ---
            news_items = fetch_news_newsdata(list(watchlist)[:100])
            for art in news_items:
                severity = score_news(art)
                if severity == "LOW":
                    continue
                if already_seen(conn, "news", art.get("title", "")[:100], severity):
                    continue
                data = {
                    "source": "news",
                    "ticker": "MULTI",
                    "event_type": "news",
                    "role_flag": None,
                    "severity": severity,
                    "title": art.get("title"),
                    "link": art.get("url"),
                    "raw": art.get("description", "")
                }
                save_event(conn, data)
                desc = f"**Headline:** {art.get('title')}\n\n{art.get('description')}"
                post_to_discord({
                    "title": f"News Alert — {severity}",
                    "description": desc,
                    "link": art.get("url"),
                    "ticker": data["ticker"],
                    "source": "NewsData.io",
                    "severity": severity
                })
                logging.info(f"Posted news alert: {art.get('title')} ({severity})")

        except Exception as e:
            logging.error(f"Main loop error: {e}")

        time.sleep(POLL_INTERVAL)

# ------------------- ENTRY -------------------
if __name__ == "__main__":
    main_loop()
# Out:
# <ipython-input-1-d1abdb2f2c76>:235: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-11-08 16:49:27,416 [INFO] Loaded 503 S&P500 tickers.
# 2025-11-08 16:49:27,419 [INFO] Bot started successfully.
# 2025-11-08 16:49:27,419 [INFO] Bot started successfully.
# 2025-11-08 16:49:28,243 [INFO] Fetched 40 Form4 entries from SEC.
# 2025-11-08 16:49:29,173 [INFO] NewsData batch ok (10 total so far)
# 2025-11-08 16:49:31,731 [INFO] NewsData batch ok (20 total so far)
# 2025-11-08 16:49:34,149 [INFO] NewsData batch ok (30 total so far)
# 2025-11-08 16:49:36,728 [INFO] NewsData batch ok (40 total so far)
# 2025-11-08 16:49:39,110 [INFO] NewsData batch ok (50 total so far)
# 2025-11-08 16:49:41,542 [INFO] NewsData batch ok (60 total so far)
# 2025-11-08 16:49:43,963 [INFO] NewsData batch ok (70 total so far)
# 2025-11-08 16:49:46,445 [INFO] NewsData batch ok (80 total so far)
# 2025-11-08 16:49:48,910 [INFO] NewsData batch ok (90 total so far)
# 2025-11-08 16:49:51,437 [INFO] NewsData batch ok (100 total so far)
# 2025-11-08 16:49:53,898 [INFO] NewsData batch ok (110 total so far)
# 2025-11-08 16:49:56,363 [INFO] NewsData batch ok (120 total so far)
# 2025-11-08 16:49:58,778 [INFO] NewsData batch ok (130 total so far)
# 2025-11-08 16:50:00,280 [INFO] Fetched 130 total news articles from NewsData.io.
# <ipython-input-1-d1abdb2f2c76>:83: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   time_threshold = (datetime.utcnow() - timedelta(minutes=DEDUPE_MINUTES)).isoformat()
# <ipython-input-1-d1abdb2f2c76>:104: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.utcnow().isoformat()
# <ipython-input-1-d1abdb2f2c76>:217: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# 2025-11-08 16:50:01,198 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:50:01,880 [ERROR] Discord error 400: {"embeds": ["0"]}
# 2025-11-08 16:50:01,883 [INFO] Posted news alert: Microsoft lets shopping bots loose in a sandbox (MED)
# 2025-11-08 16:50:02,729 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:50:03,535 [INFO] Posted news alert: UPS, GE, Boeing served lawsuit in wake of deadly Louisville plane crash (MED)
# 2025-11-08 16:50:04,305 [INFO] Posted news alert: Take-Two Interactive Software (NASDAQ:TTWO) Issues Quarterly Earnings Results, Beats Estimates By $0.13 EPS (MED)
# 2025-11-08 16:50:05,208 [INFO] Posted news alert: Acorn Energy (NASDAQ:ACFN) Posts Quarterly Earnings Results (MED)
# 2025-11-08 16:50:06,041 [INFO] Posted news alert: Chime Financial (NASDAQ:CHYM) Price Target Lowered to $24.00 at UBS Group (MED)
# 2025-11-08 16:50:06,760 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:50:07,946 [INFO] Posted news alert: JPMorgan Chase & Co. Issues Positive Forecast for Iron Mountain (NYSE:IRM) Stock Price (MED)
# 2025-11-08 16:51:38,815 [INFO] Fetched 40 Form4 entries from SEC.
# 2025-11-08 16:51:39,751 [INFO] NewsData batch ok (10 total so far)
# 2025-11-08 16:51:42,318 [INFO] NewsData batch ok (20 total so far)
# 2025-11-08 16:51:44,838 [INFO] NewsData batch ok (30 total so far)
# 2025-11-08 16:51:47,412 [INFO] NewsData batch ok (40 total so far)
# 2025-11-08 16:51:49,830 [INFO] NewsData batch ok (50 total so far)
# 2025-11-08 16:51:52,245 [INFO] NewsData batch ok (60 total so far)
# 2025-11-08 16:51:54,687 [INFO] NewsData batch ok (70 total so far)
# 2025-11-08 16:51:57,110 [INFO] NewsData batch ok (80 total so far)
# 2025-11-08 16:51:59,505 [INFO] NewsData batch ok (90 total so far)
# 2025-11-08 16:52:01,970 [INFO] NewsData batch ok (100 total so far)
# 2025-11-08 16:52:04,414 [INFO] NewsData batch ok (110 total so far)
# 2025-11-08 16:52:06,851 [INFO] NewsData batch ok (120 total so far)
# 2025-11-08 16:52:09,337 [INFO] NewsData batch ok (130 total so far)
# 2025-11-08 16:52:10,840 [INFO] Fetched 130 total news articles from NewsData.io.
# 2025-11-08 16:52:12,017 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:52:12,850 [INFO] Posted news alert: CRH (NYSE:CRH) Announces Quarterly Earnings Results, Beats Expectations By $0.27 EPS (MED)
# 2025-11-08 16:52:13,713 [INFO] Posted news alert: NexGen Energy (NYSE:NXE) Releases Quarterly Earnings Results, Misses Expectations By $0.01 EPS (MED)
# 2025-11-08 16:52:14,525 [INFO] Posted news alert: Liberty Media Corporation – Liberty Formula One Series C (NASDAQ:FWONK) Announces Earnings Results, Misses Estimates By $0.18 EPS (MED)
# 2025-11-08 16:52:15,277 [INFO] Posted news alert: Burford Capital (NYSE:BUR) Posts Earnings Results, Misses Expectations By $0.39 EPS (MED)
# 2025-11-08 16:52:16,246 [INFO] Posted news alert: Eyepoint Pharmaceuticals (NASDAQ:EYPT) Posts Quarterly Earnings Results, Misses Expectations By $0.08 EPS (MED)
# 2025-11-08 16:52:17,007 [INFO] Posted news alert: LegalZoom.com (NASDAQ:LZ) Announces Quarterly Earnings Results (MED)
# 2025-11-08 16:52:17,923 [INFO] Posted news alert: Corpay (NYSE:CPAY) Announces Quarterly Earnings Results (MED)
# 2025-11-08 16:52:18,693 [INFO] Posted news alert: UPS, GE, Boeing served lawsuit in wake of deadly Louisville plane crash (MED)
# 2025-11-08 16:52:19,638 [INFO] Posted news alert: Take-Two Interactive Software (NASDAQ:TTWO) Issues Quarterly Earnings Results, Beats Estimates By $0.13 EPS (MED)
# 2025-11-08 16:52:20,332 [INFO] Posted news alert: Acorn Energy (NASDAQ:ACFN) Posts Quarterly Earnings Results (MED)
# 2025-11-08 16:52:21,309 [INFO] Posted news alert: Chime Financial (NASDAQ:CHYM) Price Target Lowered to $24.00 at UBS Group (MED)
# 2025-11-08 16:52:22,016 [INFO] Posted news alert: CRH (NYSE:CRH) Announces Quarterly Earnings Results, Beats Expectations By $0.27 EPS (MED)
# 2025-11-08 16:52:22,781 [INFO] Posted news alert: NexGen Energy (NYSE:NXE) Releases Quarterly Earnings Results, Misses Expectations By $0.01 EPS (MED)
# 2025-11-08 16:52:23,686 [INFO] Posted news alert: Liberty Media Corporation – Liberty Formula One Series C (NASDAQ:FWONK) Announces Earnings Results, Misses Estimates By $0.18 EPS (MED)
# 2025-11-08 16:52:24,414 [INFO] Posted news alert: Burford Capital (NYSE:BUR) Posts Earnings Results, Misses Expectations By $0.39 EPS (MED)
# 2025-11-08 16:52:25,146 [INFO] Posted news alert: Eyepoint Pharmaceuticals (NASDAQ:EYPT) Posts Quarterly Earnings Results, Misses Expectations By $0.08 EPS (MED)
# 2025-11-08 16:52:25,979 [INFO] Posted news alert: LegalZoom.com (NASDAQ:LZ) Announces Quarterly Earnings Results (MED)
# 2025-11-08 16:52:26,688 [INFO] Posted news alert: Corpay (NYSE:CPAY) Announces Quarterly Earnings Results (MED)
# 2025-11-08 16:52:27,471 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:52:28,181 [INFO] Posted news alert: JPMorgan Chase & Co. Issues Positive Forecast for Iron Mountain (NYSE:IRM) Stock Price (MED)
# 2025-11-08 16:53:58,968 [INFO] Fetched 40 Form4 entries from SEC.
# 2025-11-08 16:54:00,065 [INFO] NewsData batch ok (10 total so far)
# 2025-11-08 16:54:02,562 [INFO] NewsData batch ok (20 total so far)
# 2025-11-08 16:54:04,998 [INFO] NewsData batch ok (30 total so far)
# 2025-11-08 16:54:07,456 [INFO] NewsData batch ok (40 total so far)
# 2025-11-08 16:54:09,933 [INFO] NewsData batch ok (50 total so far)
# 2025-11-08 16:54:12,361 [INFO] NewsData batch ok (60 total so far)
# 2025-11-08 16:54:14,820 [INFO] NewsData batch ok (70 total so far)
# 2025-11-08 16:54:17,301 [INFO] NewsData batch ok (80 total so far)
# 2025-11-08 16:54:19,861 [INFO] NewsData batch ok (90 total so far)
# 2025-11-08 16:54:22,305 [INFO] NewsData batch ok (100 total so far)
# 2025-11-08 16:54:24,746 [INFO] NewsData batch ok (110 total so far)
# 2025-11-08 16:54:27,188 [INFO] NewsData batch ok (120 total so far)
# 2025-11-08 16:54:29,638 [INFO] NewsData batch ok (130 total so far)
# 2025-11-08 16:54:31,140 [INFO] Fetched 130 total news articles from NewsData.io.
# 2025-11-08 16:54:31,789 [ERROR] Discord error 400: {"embeds": ["0"]}
# 2025-11-08 16:54:31,799 [INFO] Posted news alert: Microsoft lets shopping bots loose in a sandbox (MED)
# 2025-11-08 16:54:32,720 [INFO] Posted news alert: Moody’s downgrades ride-hailing firm Ola’s rating; flags risk of covenant breach (MED)
# 2025-11-08 16:54:33,663 [INFO] Posted news alert: Fiverr International (NYSE:FVRR) Reaches New 12-Month Low – What’s Next? (MED)
# 2025-11-08 16:54:34,444 [INFO] Posted news alert: Rapport Therapeutics (NASDAQ:RAPP) Releases Earnings Results, Beats Expectations By $0.06 EPS (MED)
# 2025-11-08 16:54:35,151 [INFO] Posted news alert: QUALCOMM (NASDAQ:QCOM) Announces Earnings Results, Beats Expectations By $0.13 EPS (MED)
# 2025-11-08 16:54:36,214 [INFO] Posted news alert: Rocket Pharmaceuticals (NASDAQ:RCKT) Announces Earnings Results, Beats Expectations By $0.03 EPS (MED)
# 2025-11-08 16:54:37,111 [INFO] Posted news alert: UPS, GE, Boeing served lawsuit in wake of deadly Louisville plane crash (MED)
# 2025-11-08 16:54:37,811 [INFO] Posted news alert: Take-Two Interactive Software (NASDAQ:TTWO) Issues Quarterly Earnings Results, Beats Estimates By $0.13 EPS (MED)
# 2025-11-08 16:54:38,489 [INFO] Posted news alert: Quantum Biopharma (NASDAQ:QNTM) Announces Earnings Results (MED)
# 2025-11-08 16:54:39,221 [INFO] Posted news alert: Quantum Biopharma (NASDAQ:QNTM) Releases Quarterly Earnings Results (MED)
# 2025-11-08 16:54:40,096 [INFO] Posted news alert: Acorn Energy (NASDAQ:ACFN) Posts Quarterly Earnings Results (MED)
# 2025-11-08 16:54:40,827 [INFO] Posted news alert: Chime Financial (NASDAQ:CHYM) Price Target Lowered to $24.00 at UBS Group (MED)
# 2025-11-08 16:54:41,575 [INFO] Posted news alert: [Anambra Election 2025] D-Day is here: Attention shifts to 5,718 polling units (MED)
# 2025-11-08 16:54:42,287 [INFO] Posted news alert: Rapport Therapeutics (NASDAQ:RAPP) Releases Earnings Results, Beats Expectations By $0.06 EPS (MED)
# 2025-11-08 16:54:43,047 [INFO] Posted news alert: QUALCOMM (NASDAQ:QCOM) Announces Earnings Results, Beats Expectations By $0.13 EPS (MED)
# 2025-11-08 16:54:43,706 [INFO] Posted news alert: Rocket Pharmaceuticals (NASDAQ:RCKT) Announces Earnings Results, Beats Expectations By $0.03 EPS (MED)
# 2025-11-08 16:54:44,496 [INFO] Posted news alert: Protagonist Therapeutics (NASDAQ:PTGX) Posts Quarterly Earnings Results, Misses Estimates By $0.03 EPS (MED)
# 2025-11-08 16:54:46,887 [INFO] Posted news alert: Avita Medical (NASDAQ:RCEL) Releases Quarterly Earnings Results, Misses Expectations By $0.03 EPS (MED)
# 2025-11-08 16:54:47,710 [INFO] Posted news alert: Rani Therapeutics (NASDAQ:RANI) Posts Quarterly Earnings Results, Misses Expectations By $0.03 EPS (MED)
# 2025-11-08 16:54:48,423 [INFO] Posted news alert: JPMorgan Chase & Co. Issues Positive Forecast for Iron Mountain (NYSE:IRM) Stock Price (MED)
